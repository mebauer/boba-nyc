# %% [markdown]
# # Retrieving Bubble Tea Shops in NYC Using Yelp Fusion API
#
# Mark Bauer

# %%
# importing libraries
import os
import pandas as pd
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt
import requests
from decouple import AutoConfig

# %%
# API only returns 1,000 results and 50 per request
# we use the offset parameter to page through to the next 50
# source: https://www.yelp.com/developers/faq

# saving my api key as an environment variable
API_KEY = os.environ.get('YELP_API')
if API_KEY is None:
    config = AutoConfig(search_path = '.')
    API_KEY = config('YELP_API')

# empty list to place our data for each page
lst = []

# our offset parameter - each page 50 rows
offset = 0
print('initial offset number: {}'.format(offset))

# loop through the api 20 times (limit is 1000 rows with each page includes 50 rows)
for i in range(20):
    
    try:
        headers = {'Authorization': 'Bearer {}'.format(API_KEY)}
        search_api_url = 'https://api.yelp.com/v3/businesses/search'
        params = {
                  'term': 'bubble tea', 
                  'categories': 'bubbletea, boba',
                  'location': 'New York City',
                  'offset': offset,
                  'limit': 50}

        response = requests.get(search_api_url, 
                                headers=headers, 
                                params=params, 
                                timeout=10)

        # return a dictionary
        data_dict = response.json()
        
        # convert the business dictionary to a pandas dataframe
        data = pd.DataFrame(data_dict['businesses'])
        # append dataframe to list
        lst.append(data)
      
        # add 50 to the offset to access a new page
        offset += 50
        print('current offset number: {}'.format(offset))
        
    except Exception as ex:
        print('exception: {}\nexit loop.'.format(ex))
        break

# concatenate all pages to one dataframe
df = pd.concat(lst)
df = df.reset_index(drop=True)

rows, columns = df.shape
print()
print('query includes {:,} rows and {} columns.'.format(rows, columns))
print('row id is unique: {}.'.format(df['id'].is_unique))

if df['id'].is_unique == False:
    duplicates = df.loc[df.duplicated(subset=['id'])]
    vals = list(duplicates.head()['name'].values)
    print('\nduplicates found: {}.'.format(vals))
    
    df = df.drop_duplicates(subset=['id']).reset_index(drop=True)
    print('dropping duplicates...')
    
    rows, columns = df.shape
    print('\nrow id is unique: {}.'.format(df['id'].is_unique))
    print('query includes {:,} rows and {} columns.'.format(rows, columns))
# Out:
# initial offset number: 0
# current offset number: 50
# current offset number: 100
# current offset number: 150
# current offset number: 200
# current offset number: 250
# current offset number: 300
# current offset number: 350
# current offset number: 400
# current offset number: 450
# current offset number: 500
# current offset number: 550
# current offset number: 600
# current offset number: 650
# current offset number: 700
# current offset number: 750
# current offset number: 800
# current offset number: 850
# current offset number: 900
# current offset number: 950
# current offset number: 1000
#
# query includes 543 rows and 16 columns.
# row id is unique: False.
#
# duplicates found: ['Namas Tea Garden'].
# dropping duplicates...
#
# row id is unique: True.
# query includes 542 rows and 16 columns.

# %%
df.head()
# Out:
#                        id                             alias  \
# 0  Pb5WVn8D5Xj26zpc9PutUw         wanpo-tea-shop-new-york-3
# 1  bVJQEeRNi34-3XN_F1AZEg             xing-fu-tang-new-york
# 2  Q3fmTHT7zilDWtfzLK9lMA                truedan-new-york-3
# 3  3aypSFXLfkAL4dhHVFobKg           lazy-sundaes-new-york-6
# 4  zupVwJAFYkHDwrsQd2ktXA  fiftylan-union-square-new-york-3
#
#                     name                                          image_url  \
# 0         Wanpo Tea Shop  https://s3-media2.fl.yelpcdn.com/bphoto/nGx1Qx...
# 1           Xing Fu Tang  https://s3-media2.fl.yelpcdn.com/bphoto/cyFHFE...
# 2                Truedan  https://s3-media2.fl.yelpcdn.com/bphoto/BmUZXO...
# 3           Lazy Sundaes  https://s3-media3.fl.yelpcdn.com/bphoto/kEfCYC...
# 4  FIFTYLAN Union Square  https://s3-media3.fl.yelpcdn.com/bphoto/UIwR20...
#
#    is_closed                                                url  review_count  \
# 0      False  https://www.yelp.com/biz/wanpo-tea-shop-new-yo...            29
# 1      False  https://www.yelp.com/biz/xing-fu-tang-new-york...            73
# 2      False  https://www.yelp.com/biz/truedan-new-york-3?ad...            97
# 3      False  https://www.yelp.com/biz/lazy-sundaes-new-york...            29
# 4      False  https://www.yelp.com/biz/fiftylan-union-square...            56
#
#                                           categories  rating  \
# 0    [{'alias': 'bubbletea', 'title': 'Bubble Tea'}]     4.5
# 1    [{'alias': 'bubbletea', 'title': 'Bubble Tea'}]     4.5
# 2    [{'alias': 'bubbletea', 'title': 'Bubble Tea'}]     4.5
# 3  [{'alias': 'bubbletea', 'title': 'Bubble Tea'}...     4.5
# 4    [{'alias': 'bubbletea', 'title': 'Bubble Tea'}]     4.0
#
#                                          coordinates        transactions  \
# 0  {'latitude': 40.73155209065394, 'longitude': -...  [delivery, pickup]
# 1      {'latitude': 40.7288, 'longitude': -73.98775}  [delivery, pickup]
# 2  {'latitude': 40.7191742, 'longitude': -73.9962...  [delivery, pickup]
# 3   {'latitude': 40.720597, 'longitude': -73.984539}  [delivery, pickup]
# 4   {'latitude': 40.735516, 'longitude': -73.989191}  [delivery, pickup]
#
#   price                                           location         phone  \
# 0    $$  {'address1': '37 E 8th St', 'address2': '', 'a...  +12129958349
# 1   NaN  {'address1': '133 2nd Ave', 'address2': '', 'a...
# 2    $$  {'address1': '208 Grand St', 'address2': None,...  +16465592886
# 3    $$  {'address1': '23 Clinton St', 'address2': None...
# 4   NaN  {'address1': '32 Union Square E', 'address2': ...  +16467670085
#
#     display_phone     distance
# 0  (212) 995-8349  2903.009527
# 1                  2656.450427
# 2  (646) 559-2886  1535.241614
# 3                  1877.016204
# 4  (646) 767-0085  3367.900728

# %%
df.tail()
# Out:
#                          id                   alias           name  \
# 537  QBebLBqhiuDlWasPgp6s4Q        tbaar-flushing-5          Tbaar
# 538  Vz6hbICqQfyMWq9wzAKakw        tbaar-flushing-4          TBaar
# 539  7apqk24GsFC9dptoD5dDZg  uncleman-cafe-new-york  Uncleman Cafe
# 540  YBgAPbviWYtVP2gAUhc7_A         t-baar-flushing         T Baar
# 541  f5UVQXvDpOrrIZdCjsw47w    maxins-cafe-flushing   Maxin's Cafe
#
#                                              image_url  is_closed  \
# 537  https://s3-media1.fl.yelpcdn.com/bphoto/bgao-b...      False
# 538  https://s3-media1.fl.yelpcdn.com/bphoto/phUYWa...      False
# 539                                                         False
# 540  https://s3-media4.fl.yelpcdn.com/bphoto/8pk-_Q...      False
# 541  https://s3-media1.fl.yelpcdn.com/bphoto/S3vWvD...      False
#
#                                                    url  review_count  \
# 537  https://www.yelp.com/biz/tbaar-flushing-5?adju...             2
# 538  https://www.yelp.com/biz/tbaar-flushing-4?adju...             6
# 539  https://www.yelp.com/biz/uncleman-cafe-new-yor...             1
# 540  https://www.yelp.com/biz/t-baar-flushing?adjus...             8
# 541  https://www.yelp.com/biz/maxins-cafe-flushing?...            15
#
#                                             categories  rating  \
# 537    [{'alias': 'bubbletea', 'title': 'Bubble Tea'}]     3.5
# 538  [{'alias': 'bubbletea', 'title': 'Bubble Tea'}...     4.0
# 539  [{'alias': 'desserts', 'title': 'Desserts'}, {...     1.0
# 540    [{'alias': 'bubbletea', 'title': 'Bubble Tea'}]     3.5
# 541  [{'alias': 'bakeries', 'title': 'Bakeries'}, {...     3.5
#
#                                            coordinates        transactions  \
# 537   {'latitude': 40.759357, 'longitude': -73.830396}  [pickup, delivery]
# 538  {'latitude': 40.7613116, 'longitude': -73.8308...                  []
# 539     {'latitude': 40.71781, 'longitude': -73.99795}                  []
# 540  {'latitude': 40.7587509, 'longitude': -73.830162}                  []
# 541      {'latitude': 40.7585, 'longitude': -73.83064}                  []
#
#     price                                           location         phone  \
# 537   NaN  {'address1': '135-52 Roosevelt Ave', 'address2...
# 538   NaN  {'address1': '37-11 Main St', 'address2': '', ...
# 539   NaN  {'address1': '122 Mulberry St', 'address2': No...  +12129666206
# 540     $  {'address1': '135-36 40th Rd', 'address2': '',...
# 541     $  {'address1': '135-24 40th Rd', 'address2': '',...  +17188869200
#
#       display_phone      distance
# 537                  15054.917573
# 538                  15147.410738
# 539  (212) 966-6206   1414.238245
# 540                  15045.970192
# 541  (718) 886-9200  14997.842205

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 542 entries, 0 to 541
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             542 non-null    object
#  1   alias          542 non-null    object
#  2   name           542 non-null    object
#  3   image_url      542 non-null    object
#  4   is_closed      542 non-null    bool
#  5   url            542 non-null    object
#  6   review_count   542 non-null    int64
#  7   categories     542 non-null    object
#  8   rating         542 non-null    float64
#  9   coordinates    542 non-null    object
#  10  transactions   542 non-null    object
#  11  price          328 non-null    object
#  12  location       542 non-null    object
#  13  phone          542 non-null    object
#  14  display_phone  542 non-null    object
#  15  distance       542 non-null    float64
# dtypes: bool(1), float64(2), int64(1), object(12)
# memory usage: 64.2+ KB

# %%
df['name'].value_counts()
# Out:
# Gong Cha                  36
# Kung Fu Tea               34
# ViVi Bubble Tea           21
# Möge Tee                  10
# CoCo Fresh Tea & Juice     8
#                           ..
# ÜMACHA                     1
# Tea Hub                    1
# ViVi Bubble tea            1
# Bread & Joe                1
# Maxin's Cafe               1
# Name: name, Length: 360, dtype: int64

# %%
df['name'].value_counts().head(20)
# Out:
# Gong Cha                       36
# Kung Fu Tea                    34
# ViVi Bubble Tea                21
# Möge Tee                       10
# CoCo Fresh Tea & Juice          8
# Vivi Bubble Tea                 6
# Coco Fresh Tea & Juice          6
# Tiger Sugar                     5
# Banhmigos                       4
# TBaar                           4
# Real Fruit Bubble Tea           4
# Chun Yang Tea                   4
# Hawa Smoothies & Bubble Tea     4
# Meet Fresh                      3
# Yaya Tea Garden                 3
# Tornado Crepe                   3
# Mr. Wish                        3
# Teazzi Tea Shop                 3
# Yifang Taiwan Fruit Tea         3
# Tbaar                           3
# Name: name, dtype: int64

# %%
df['categories'][0]
# Out:
# [{'alias': 'bubbletea', 'title': 'Bubble Tea'}]

# %%
gdf = pd.concat([df, df['coordinates'].apply(pd.Series)], axis=1)

gdf = gpd.GeoDataFrame(gdf, crs=4326, 
      geometry=gpd.points_from_xy(gdf.longitude, gdf.latitude))

gdf.head()
# Out:
#                        id                             alias  \
# 0  Pb5WVn8D5Xj26zpc9PutUw         wanpo-tea-shop-new-york-3
# 1  bVJQEeRNi34-3XN_F1AZEg             xing-fu-tang-new-york
# 2  Q3fmTHT7zilDWtfzLK9lMA                truedan-new-york-3
# 3  3aypSFXLfkAL4dhHVFobKg           lazy-sundaes-new-york-6
# 4  zupVwJAFYkHDwrsQd2ktXA  fiftylan-union-square-new-york-3
#
#                     name                                          image_url  \
# 0         Wanpo Tea Shop  https://s3-media2.fl.yelpcdn.com/bphoto/nGx1Qx...
# 1           Xing Fu Tang  https://s3-media2.fl.yelpcdn.com/bphoto/cyFHFE...
# 2                Truedan  https://s3-media2.fl.yelpcdn.com/bphoto/BmUZXO...
# 3           Lazy Sundaes  https://s3-media3.fl.yelpcdn.com/bphoto/kEfCYC...
# 4  FIFTYLAN Union Square  https://s3-media3.fl.yelpcdn.com/bphoto/UIwR20...
#
#    is_closed                                                url  review_count  \
# 0      False  https://www.yelp.com/biz/wanpo-tea-shop-new-yo...            29
# 1      False  https://www.yelp.com/biz/xing-fu-tang-new-york...            73
# 2      False  https://www.yelp.com/biz/truedan-new-york-3?ad...            97
# 3      False  https://www.yelp.com/biz/lazy-sundaes-new-york...            29
# 4      False  https://www.yelp.com/biz/fiftylan-union-square...            56
#
#                                           categories  rating  \
# 0    [{'alias': 'bubbletea', 'title': 'Bubble Tea'}]     4.5
# 1    [{'alias': 'bubbletea', 'title': 'Bubble Tea'}]     4.5
# 2    [{'alias': 'bubbletea', 'title': 'Bubble Tea'}]     4.5
# 3  [{'alias': 'bubbletea', 'title': 'Bubble Tea'}...     4.5
# 4    [{'alias': 'bubbletea', 'title': 'Bubble Tea'}]     4.0
#
#                                          coordinates        transactions  \
# 0  {'latitude': 40.73155209065394, 'longitude': -...  [delivery, pickup]
# 1      {'latitude': 40.7288, 'longitude': -73.98775}  [delivery, pickup]
# 2  {'latitude': 40.7191742, 'longitude': -73.9962...  [delivery, pickup]
# 3   {'latitude': 40.720597, 'longitude': -73.984539}  [delivery, pickup]
# 4   {'latitude': 40.735516, 'longitude': -73.989191}  [delivery, pickup]
#
#   price                                           location         phone  \
# 0    $$  {'address1': '37 E 8th St', 'address2': '', 'a...  +12129958349
# 1   NaN  {'address1': '133 2nd Ave', 'address2': '', 'a...
# 2    $$  {'address1': '208 Grand St', 'address2': None,...  +16465592886
# 3    $$  {'address1': '23 Clinton St', 'address2': None...
# 4   NaN  {'address1': '32 Union Square E', 'address2': ...  +16467670085
#
#     display_phone     distance   latitude  longitude  \
# 0  (212) 995-8349  2903.009527  40.731552 -73.994160
# 1                  2656.450427  40.728800 -73.987750
# 2  (646) 559-2886  1535.241614  40.719174 -73.996220
# 3                  1877.016204  40.720597 -73.984539
# 4  (646) 767-0085  3367.900728  40.735516 -73.989191
#
#                      geometry
# 0  POINT (-73.99416 40.73155)
# 1  POINT (-73.98775 40.72880)
# 2  POINT (-73.99622 40.71917)
# 3  POINT (-73.98454 40.72060)
# 4  POINT (-73.98919 40.73552)

# %%
url = 'https://data.cityofnewyork.us/api/geospatial/tqmj-j8zm?method=export&format=Shapefile'
boro_gdf = gpd.read_file(url)

boro_gdf.head()
# Out:
#    boro_code      boro_name    shape_area     shape_leng  \
# 0        1.0      Manhattan  6.366208e+08  359993.127161
# 1        2.0          Bronx  1.187194e+09  463868.935588
# 2        3.0       Brooklyn  1.934174e+09  728195.194837
# 3        5.0  Staten Island  1.623631e+09  325924.002252
# 4        4.0         Queens  3.040206e+09  900269.281914
#
#                                             geometry
# 0  MULTIPOLYGON (((-74.01093 40.68449, -74.01193 ...
# 1  MULTIPOLYGON (((-73.89681 40.79581, -73.89694 ...
# 2  MULTIPOLYGON (((-73.86327 40.58388, -73.86381 ...
# 3  MULTIPOLYGON (((-74.05051 40.56642, -74.05047 ...
# 4  MULTIPOLYGON (((-73.82645 40.59053, -73.82642 ...

# %%
fig, ax = plt.subplots(figsize=(8, 8))

gdf.plot(ax=ax)
boro_gdf.plot(ax=ax, facecolor='None', edgecolor='black', zorder=0)

plt.title('bubble tea shops in NYC area')
plt.tight_layout()

# %%
gdf = gpd.clip(gdf, boro_gdf)
gdf = gdf.reset_index(drop=True)

gdf.shape
# Out:
# C:\Users\datal\AppData\Local\Temp\ipykernel_35780\2316523936.py:1: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: EPSG:4326
# Right CRS: GEOGCS["WGS84(DD)",DATUM["WGS84",SPHEROID["WGS84", ...
#
#   gdf = gpd.clip(gdf, boro_gdf)
# (404, 19)

# %%
gdf.head()
# Out:
#                        id                                 alias  \
# 0  BLnq_CETaoJYQB7U3IxGCw     mr-chicken-and-mrs-tea-ozone-park
# 1  1IwCoN9jVu4O-jaeEKH83w        halo-kitchen-and-lounge-queens
# 2  j5x37Ozo9hc3--zdMnZfEA  pop-pot-noodle-and-tea-spot-queens-2
# 3  AQqUiXi0hn1xu5qVfM54IQ        beijing-dumpling-house-jamaica
# 4  -E5PfobEXNQ_WC8Qv2wGJA      halal-china-kitchen-plus-jamaica
#
#                         name  \
# 0       Mr.Chicken & Mrs.Tea
# 1      Halo Kitchen & Lounge
# 2  Pop Pot Noodle & Tea Spot
# 3     Beijing Dumpling House
# 4   Halal China Kitchen Plus
#
#                                            image_url  is_closed  \
# 0  https://s3-media2.fl.yelpcdn.com/bphoto/QLxNJs...      False
# 1  https://s3-media2.fl.yelpcdn.com/bphoto/s7DKo7...      False
# 2  https://s3-media2.fl.yelpcdn.com/bphoto/SDb9ck...      False
# 3  https://s3-media3.fl.yelpcdn.com/bphoto/w93mGy...      False
# 4  https://s3-media4.fl.yelpcdn.com/bphoto/lnj0lA...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/mr-chicken-and-mrs-te...            96
# 1  https://www.yelp.com/biz/halo-kitchen-and-loun...            12
# 2  https://www.yelp.com/biz/pop-pot-noodle-and-te...            16
# 3  https://www.yelp.com/biz/beijing-dumpling-hous...           332
# 4  https://www.yelp.com/biz/halal-china-kitchen-p...            34
#
#                                           categories  rating  \
# 0  [{'alias': 'chicken_wings', 'title': 'Chicken ...     4.5
# 1  [{'alias': 'bubbletea', 'title': 'Bubble Tea'}...     2.5
# 2    [{'alias': 'bubbletea', 'title': 'Bubble Tea'}]     4.0
# 3  [{'alias': 'bubbletea', 'title': 'Bubble Tea'}...     4.5
# 4  [{'alias': 'chinese', 'title': 'Chinese'}, {'a...     3.5
#
#                                          coordinates        transactions  \
# 0  {'latitude': 40.6698487, 'longitude': -73.8423...  [pickup, delivery]
# 1  {'latitude': 40.68871402307153, 'longitude': -...  [pickup, delivery]
# 2     {'latitude': 40.69123, 'longitude': -73.86614}  [delivery, pickup]
# 3  {'latitude': 40.7043147, 'longitude': -73.8091...  [pickup, delivery]
# 4  {'latitude': 40.7081726, 'longitude': -73.8032...  [pickup, delivery]
#
#   price                                           location         phone  \
# 0   NaN  {'address1': '150-29 Crossbay Blvd', 'address2...  +13475350010
# 1   NaN  {'address1': '12710 Liberty Ave', 'address2': ...  +19293860928
# 2   NaN  {'address1': '7508 Jamaica Ave', 'address2': N...
# 3     $  {'address1': '88-38 Sutphin Blvd', 'address2':...  +17182972935
# 4   NaN  {'address1': '87-48 Parsons Blvd', 'address2':...  +17185261300
#
#     display_phone      distance   latitude  longitude  \
# 0  (347) 535-0010  13456.986110  40.669849 -73.842308
# 1  (929) 386-0928  15021.671634  40.688714 -73.817481
# 2                  10916.154176  40.691230 -73.866140
# 3  (718) 297-2935  15613.386874  40.704315 -73.809180
# 4  (718) 526-1300  16108.411529  40.708173 -73.803248
#
#                      geometry
# 0  POINT (-73.84231 40.66985)
# 1  POINT (-73.81748 40.68871)
# 2  POINT (-73.86614 40.69123)
# 3  POINT (-73.80918 40.70431)
# 4  POINT (-73.80325 40.70817)

# %%
fig, ax = plt.subplots(figsize=(8, 8))

gdf.plot(ax=ax)
boro_gdf.plot(ax=ax, facecolor='None', edgecolor='black', zorder=0)

plt.title('bubble tea shops in NYC')
plt.tight_layout()

# %%
# # save file
# gdf.to_csv('boba-nyc.csv', index=False)

# %%
# # sanity check
# pd.read_csv('boba-nyc.csv').head()
