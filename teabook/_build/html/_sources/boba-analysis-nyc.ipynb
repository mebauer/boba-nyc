# %% [markdown]
# # Obsessed with Boba? Analyzing Bubble Tea Shops in NYC Using the Yelp Fusion API
# Exploratory Data Analysis

# %%
import pandas as pd
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt
import seaborn as sns
import requests
from PIL import Image

# %matplotlib inline
sns.set(color_codes=True)

# %%
# read in data and preview first five rows
df = pd.read_csv('boba-nyc.csv')

df.head()
# Out:
#                        id                             alias  \
# 0  Q3fmTHT7zilDWtfzLK9lMA                truedan-new-york-3
# 1  7-bx74TooPuZKZDNW4WFcQ            chun-yang-tea-new-york
# 2  3aypSFXLfkAL4dhHVFobKg           lazy-sundaes-new-york-6
# 3  bVJQEeRNi34-3XN_F1AZEg             xing-fu-tang-new-york
# 4  zupVwJAFYkHDwrsQd2ktXA  fiftylan-union-square-new-york-3
#
#                     name                                          image_url  \
# 0                Truedan  https://s3-media2.fl.yelpcdn.com/bphoto/BmUZXO...
# 1          Chun Yang Tea  https://s3-media1.fl.yelpcdn.com/bphoto/JrGwrZ...
# 2           Lazy Sundaes  https://s3-media3.fl.yelpcdn.com/bphoto/kEfCYC...
# 3           Xing Fu Tang  https://s3-media2.fl.yelpcdn.com/bphoto/cyFHFE...
# 4  FIFTYLAN Union Square  https://s3-media3.fl.yelpcdn.com/bphoto/UIwR20...
#
#    is_closed                                                url  review_count  \
# 0      False  https://www.yelp.com/biz/truedan-new-york-3?ad...            99
# 1      False  https://www.yelp.com/biz/chun-yang-tea-new-yor...            91
# 2      False  https://www.yelp.com/biz/lazy-sundaes-new-york...            32
# 3      False  https://www.yelp.com/biz/xing-fu-tang-new-york...            89
# 4      False  https://www.yelp.com/biz/fiftylan-union-square...            59
#
#                                           categories  rating  \
# 0    [{'alias': 'bubbletea', 'title': 'Bubble Tea'}]     4.5
# 1    [{'alias': 'bubbletea', 'title': 'Bubble Tea'}]     4.5
# 2  [{'alias': 'bubbletea', 'title': 'Bubble Tea'}...     4.5
# 3    [{'alias': 'bubbletea', 'title': 'Bubble Tea'}]     4.5
# 4    [{'alias': 'bubbletea', 'title': 'Bubble Tea'}]     4.0
#
#                                          coordinates            transactions  \
# 0  {'latitude': 40.7191742, 'longitude': -73.9962...  ['delivery', 'pickup']
# 1      {'latitude': 40.71617, 'longitude': -73.9971}  ['delivery', 'pickup']
# 2   {'latitude': 40.720597, 'longitude': -73.984539}  ['delivery', 'pickup']
# 3      {'latitude': 40.7288, 'longitude': -73.98775}  ['delivery', 'pickup']
# 4   {'latitude': 40.735516, 'longitude': -73.989191}  ['delivery', 'pickup']
#
#   price                                           location         phone  \
# 0    $$  {'address1': '208 Grand St', 'address2': None,...  1.646559e+10
# 1    $$  {'address1': '26B Elizabeth St', 'address2': '...  1.212420e+10
# 2    $$  {'address1': '23 Clinton St', 'address2': None...           NaN
# 3   NaN  {'address1': '133 2nd Ave', 'address2': '', 'a...           NaN
# 4   NaN  {'address1': '32 Union Square E', 'address2': ...  1.646767e+10
#
#     display_phone     distance   latitude  longitude  \
# 0  (646) 559-2886  1535.241614  40.719174 -73.996220
# 1  (212) 420-0123  1212.877370  40.716170 -73.997100
# 2             NaN  1877.016204  40.720597 -73.984539
# 3             NaN  2656.450427  40.728800 -73.987750
# 4  (646) 767-0085  3367.900728  40.735516 -73.989191
#
#                                geometry
# 0        POINT (-73.9962197 40.7191742)
# 1             POINT (-73.9971 40.71617)
# 2          POINT (-73.984539 40.720597)
# 3    POINT (-73.98775000000001 40.7288)
# 4  POINT (-73.98919100000001 40.735516)

# %%
# preview last five rows
df.tail()
# Out:
#                          id                   alias           name  \
# 408  QBebLBqhiuDlWasPgp6s4Q        tbaar-flushing-5          Tbaar
# 409  7apqk24GsFC9dptoD5dDZg  uncleman-cafe-new-york  Uncleman Cafe
# 410  Vz6hbICqQfyMWq9wzAKakw        tbaar-flushing-4          TBaar
# 411  YBgAPbviWYtVP2gAUhc7_A         t-baar-flushing         T Baar
# 412  f5UVQXvDpOrrIZdCjsw47w    maxins-cafe-flushing   Maxin's Cafe
#
#                                              image_url  is_closed  \
# 408  https://s3-media1.fl.yelpcdn.com/bphoto/bgao-b...      False
# 409                                                NaN      False
# 410  https://s3-media1.fl.yelpcdn.com/bphoto/phUYWa...      False
# 411  https://s3-media4.fl.yelpcdn.com/bphoto/8pk-_Q...      False
# 412  https://s3-media1.fl.yelpcdn.com/bphoto/S3vWvD...      False
#
#                                                    url  review_count  \
# 408  https://www.yelp.com/biz/tbaar-flushing-5?adju...             2
# 409  https://www.yelp.com/biz/uncleman-cafe-new-yor...             1
# 410  https://www.yelp.com/biz/tbaar-flushing-4?adju...             6
# 411  https://www.yelp.com/biz/t-baar-flushing?adjus...             8
# 412  https://www.yelp.com/biz/maxins-cafe-flushing?...            15
#
#                                             categories  rating  \
# 408    [{'alias': 'bubbletea', 'title': 'Bubble Tea'}]     3.5
# 409  [{'alias': 'desserts', 'title': 'Desserts'}, {...     1.0
# 410  [{'alias': 'bubbletea', 'title': 'Bubble Tea'}...     4.0
# 411    [{'alias': 'bubbletea', 'title': 'Bubble Tea'}]     3.5
# 412  [{'alias': 'bakeries', 'title': 'Bakeries'}, {...     3.5
#
#                                            coordinates  \
# 408   {'latitude': 40.759357, 'longitude': -73.830396}
# 409     {'latitude': 40.71781, 'longitude': -73.99795}
# 410  {'latitude': 40.7613116, 'longitude': -73.8308...
# 411  {'latitude': 40.7587509, 'longitude': -73.830162}
# 412      {'latitude': 40.7585, 'longitude': -73.83064}
#
#                transactions price  \
# 408  ['delivery', 'pickup']   NaN
# 409                      []   NaN
# 410                      []   NaN
# 411                      []     $
# 412                      []     $
#
#                                               location         phone  \
# 408  {'address1': '135-52 Roosevelt Ave', 'address2...           NaN
# 409  {'address1': '122 Mulberry St', 'address2': No...  1.212967e+10
# 410  {'address1': '37-11 Main St', 'address2': '', ...           NaN
# 411  {'address1': '135-36 40th Rd', 'address2': '',...           NaN
# 412  {'address1': '135-24 40th Rd', 'address2': '',...  1.718887e+10
#
#       display_phone      distance   latitude  longitude  \
# 408             NaN  15054.917573  40.759357 -73.830396
# 409  (212) 966-6206   1414.238245  40.717810 -73.997950
# 410             NaN  15147.410738  40.761312 -73.830812
# 411             NaN  15045.970192  40.758751 -73.830162
# 412  (718) 886-9200  14997.842205  40.758500 -73.830640
#
#                                  geometry
# 408  POINT (-73.83039599999999 40.759357)
# 409            POINT (-73.99795 40.71781)
# 410        POINT (-73.8308122 40.7613116)
# 411         POINT (-73.830162 40.7587509)
# 412             POINT (-73.83064 40.7585)

# %%
rows, columns = df.shape
print('number of rows: {}\nnumber of columns: {}'.format(rows, columns))
# Out:
# number of rows: 413
# number of columns: 19

# %%
# review concise summary of data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 413 entries, 0 to 412
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             413 non-null    object
#  1   alias          413 non-null    object
#  2   name           413 non-null    object
#  3   image_url      408 non-null    object
#  4   is_closed      413 non-null    bool
#  5   url            413 non-null    object
#  6   review_count   413 non-null    int64
#  7   categories     413 non-null    object
#  8   rating         413 non-null    float64
#  9   coordinates    413 non-null    object
#  10  transactions   413 non-null    object
#  11  price          258 non-null    object
#  12  location       413 non-null    object
#  13  phone          363 non-null    float64
#  14  display_phone  363 non-null    object
#  15  distance       413 non-null    float64
#  16  latitude       413 non-null    float64
#  17  longitude      413 non-null    float64
#  18  geometry       413 non-null    object
# dtypes: bool(1), float64(5), int64(1), object(12)
# memory usage: 58.6+ KB

# %%
# identifiying number of nulls and percentage of total per column
ser1 = df.isnull().sum().sort_values(ascending=False)
ser2 = round((df.isnull().sum().sort_values(ascending=False) / len(df)) * 100, 2)

pd.concat([ser1.rename('null_count'), ser2.rename('null_perc')], axis=1)
# Out:
#                null_count  null_perc
# price                 155      37.53
# display_phone          50      12.11
# phone                  50      12.11
# image_url               5       1.21
# id                      0       0.00
# transactions            0       0.00
# longitude               0       0.00
# latitude                0       0.00
# distance                0       0.00
# location                0       0.00
# coordinates             0       0.00
# alias                   0       0.00
# rating                  0       0.00
# categories              0       0.00
# review_count            0       0.00
# url                     0       0.00
# is_closed               0       0.00
# name                    0       0.00
# geometry                0       0.00

# %%
# descriptive statistics of numeric columns
df.describe()
# Out:
#        review_count      rating         phone      distance    latitude  \
# count    413.000000  413.000000  3.630000e+02    413.000000  413.000000
# mean      90.784504    3.991525  1.615045e+10   8865.304351   40.716352
# std      117.238138    0.605838  2.382773e+09   5580.328072    0.058112
# min        1.000000    1.000000  1.201432e+10    953.875131   40.537609
# 25%       16.000000    3.500000  1.347732e+10   3944.470714   40.689812
# 50%       50.000000    4.000000  1.718293e+10   8155.616841   40.731610
# 75%      117.000000    4.500000  1.718887e+10  12773.346149   40.757323
# max      740.000000    5.000000  1.934235e+10  25132.157979   40.886959
#
#         longitude
# count  413.000000
# mean   -73.943407
# std      0.082408
# min    -74.166080
# 25%    -73.994960
# 50%    -73.974950
# 75%    -73.882745
# max    -73.702410

# %%
# descriptive statistics of string/object columns
df.describe(include=['O']).T
# Out:
#               count unique                                                top  \
# id              413    413                             BNyT4ticLRnaE6SF6HTAiQ
# alias           413    413                            one-more-charm-brooklyn
# name            413    269                                        Kung Fu Tea
# image_url       408    408  https://s3-media2.fl.yelpcdn.com/bphoto/HF0y5Y...
# url             413    413  https://www.yelp.com/biz/kung-fu-tea-brooklyn-...
# categories      413    177    [{'alias': 'bubbletea', 'title': 'Bubble Tea'}]
# coordinates     413    408     {'latitude': 40.73161, 'longitude': -74.00312}
# transactions    413      5                             ['delivery', 'pickup']
# price           258      3                                                  $
# location        413    410  {'address1': '136-20 Roosevelt Ave', 'address2...
# display_phone   363    358                                     (718) 358-9188
# geometry        413    408                         POINT (-73.99471 40.71697)
#
#               freq
# id               1
# alias            1
# name            26
# image_url        1
# url              1
# categories     114
# coordinates      2
# transactions   212
# price          168
# location         2
# display_phone    2
# geometry         2

# %%
# confirm that unique id is actually unique
print('id is unique: {}'.format(df['id'].is_unique))
# Out:
# id is unique: True

# %%
df.head()
# Out:
#                        id                             alias  \
# 0  Q3fmTHT7zilDWtfzLK9lMA                truedan-new-york-3
# 1  7-bx74TooPuZKZDNW4WFcQ            chun-yang-tea-new-york
# 2  3aypSFXLfkAL4dhHVFobKg           lazy-sundaes-new-york-6
# 3  bVJQEeRNi34-3XN_F1AZEg             xing-fu-tang-new-york
# 4  zupVwJAFYkHDwrsQd2ktXA  fiftylan-union-square-new-york-3
#
#                     name                                          image_url  \
# 0                Truedan  https://s3-media2.fl.yelpcdn.com/bphoto/BmUZXO...
# 1          Chun Yang Tea  https://s3-media1.fl.yelpcdn.com/bphoto/JrGwrZ...
# 2           Lazy Sundaes  https://s3-media3.fl.yelpcdn.com/bphoto/kEfCYC...
# 3           Xing Fu Tang  https://s3-media2.fl.yelpcdn.com/bphoto/cyFHFE...
# 4  FIFTYLAN Union Square  https://s3-media3.fl.yelpcdn.com/bphoto/UIwR20...
#
#    is_closed                                                url  review_count  \
# 0      False  https://www.yelp.com/biz/truedan-new-york-3?ad...            99
# 1      False  https://www.yelp.com/biz/chun-yang-tea-new-yor...            91
# 2      False  https://www.yelp.com/biz/lazy-sundaes-new-york...            32
# 3      False  https://www.yelp.com/biz/xing-fu-tang-new-york...            89
# 4      False  https://www.yelp.com/biz/fiftylan-union-square...            59
#
#                                           categories  rating  \
# 0    [{'alias': 'bubbletea', 'title': 'Bubble Tea'}]     4.5
# 1    [{'alias': 'bubbletea', 'title': 'Bubble Tea'}]     4.5
# 2  [{'alias': 'bubbletea', 'title': 'Bubble Tea'}...     4.5
# 3    [{'alias': 'bubbletea', 'title': 'Bubble Tea'}]     4.5
# 4    [{'alias': 'bubbletea', 'title': 'Bubble Tea'}]     4.0
#
#                                          coordinates            transactions  \
# 0  {'latitude': 40.7191742, 'longitude': -73.9962...  ['delivery', 'pickup']
# 1      {'latitude': 40.71617, 'longitude': -73.9971}  ['delivery', 'pickup']
# 2   {'latitude': 40.720597, 'longitude': -73.984539}  ['delivery', 'pickup']
# 3      {'latitude': 40.7288, 'longitude': -73.98775}  ['delivery', 'pickup']
# 4   {'latitude': 40.735516, 'longitude': -73.989191}  ['delivery', 'pickup']
#
#   price                                           location         phone  \
# 0    $$  {'address1': '208 Grand St', 'address2': None,...  1.646559e+10
# 1    $$  {'address1': '26B Elizabeth St', 'address2': '...  1.212420e+10
# 2    $$  {'address1': '23 Clinton St', 'address2': None...           NaN
# 3   NaN  {'address1': '133 2nd Ave', 'address2': '', 'a...           NaN
# 4   NaN  {'address1': '32 Union Square E', 'address2': ...  1.646767e+10
#
#     display_phone     distance   latitude  longitude  \
# 0  (646) 559-2886  1535.241614  40.719174 -73.996220
# 1  (212) 420-0123  1212.877370  40.716170 -73.997100
# 2             NaN  1877.016204  40.720597 -73.984539
# 3             NaN  2656.450427  40.728800 -73.987750
# 4  (646) 767-0085  3367.900728  40.735516 -73.989191
#
#                                geometry
# 0        POINT (-73.9962197 40.7191742)
# 1             POINT (-73.9971 40.71617)
# 2          POINT (-73.984539 40.720597)
# 3    POINT (-73.98775000000001 40.7288)
# 4  POINT (-73.98919100000001 40.735516)

# %%
# identify number of unique bubble tea shop entries
names_counts = df['name'].value_counts().reset_index()
names_counts = names_counts.rename(columns={'index':'name', 'name':'counts'})

print('number of unique bubble tea shops: {}'.format(len(names_counts)))
names_counts
# Out:
# number of unique bubble tea shops: 269
#                             name  counts
# 0                    Kung Fu Tea      26
# 1                       Gong Cha      24
# 2                ViVi Bubble Tea      19
# 3                       Möge Tee       9
# 4         CoCo Fresh Tea & Juice       6
# ..                           ...     ...
# 264              ViVi Bubble tea       1
# 265  Creep City Ninja Bubble Tea       1
# 266                Newkirk Fruit       1
# 267                  Sakai Ramen       1
# 268                   Boba Fries       1
#
# [269 rows x 2 columns]

# %%
# check for duplicates - white spaces, mispellings, etc
lst = []
for row in range(len(names_counts)):
    value = names_counts['name'][row].replace(' ', '').lower()
    lst.append(value)  
    
names_counts = pd.concat([names_counts, pd.Series(lst).rename('name_lower')], axis=1)
names_counts.head()
# Out:
#                      name  counts          name_lower
# 0             Kung Fu Tea      26           kungfutea
# 1                Gong Cha      24             gongcha
# 2         ViVi Bubble Tea      19       vivibubbletea
# 3                Möge Tee       9             mögetee
# 4  CoCo Fresh Tea & Juice       6  cocofreshtea&juice

# %%
# there are duplicate entries
names_counts['name_lower'].value_counts().head(10)
# Out:
# jooyteashoppe           3
# tbaar                   3
# vivibubbletea           3
# yifangtaiwanfruittea    3
# yomie'sricexyogurt      2
# pokébowlstation         2
# cocofreshtea&juice      2
# theyuniquetea           1
# goodyfreshdimsum        1
# unclemancafe            1
# Name: name_lower, dtype: int64

# %%
# return list of duplicate entries that need to be replaced
duplicates_ser = names_counts['name_lower'].value_counts() > 1
duplicates = duplicates_ser.loc[duplicates_ser].index

duplicates.to_list()
# Out:
# ['jooyteashoppe',
#  'tbaar',
#  'vivibubbletea',
#  'yifangtaiwanfruittea',
#  "yomie'sricexyogurt",
#  'pokébowlstation',
#  'cocofreshtea&juice']

# %%
names_counts = names_counts.loc[names_counts['name_lower'].isin(duplicates.to_list())].sort_values(by='name_lower')

names_counts
# Out:
#                          name  counts            name_lower
# 4      CoCo Fresh Tea & Juice       6    cocofreshtea&juice
# 7      Coco Fresh Tea & Juice       4    cocofreshtea&juice
# 152           JOOY TEA SHOPPE       1         jooyteashoppe
# 125           JOOY Tea Shoppe       1         jooyteashoppe
# 70            Jooy Tea Shoppe       1         jooyteashoppe
# 32           PokéBowl Station       2       pokébowlstation
# 235          Pokébowl Station       1       pokébowlstation
# 8                       TBaar       4                 tbaar
# 16                      Tbaar       3                 tbaar
# 126                    T Baar       1                 tbaar
# 2             ViVi Bubble Tea      19         vivibubbletea
# 264           ViVi Bubble tea       1         vivibubbletea
# 6             Vivi Bubble Tea       5         vivibubbletea
# 36   Yi Fang Taiwan Fruit Tea       2  yifangtaiwanfruittea
# 18    Yifang Taiwan Fruit Tea       3  yifangtaiwanfruittea
# 35    YiFang Taiwan Fruit Tea       2  yifangtaiwanfruittea
# 121     Yomie's Rice x Yogurt       1    yomie'sricexyogurt
# 42      Yomie's Rice X Yogurt       1    yomie'sricexyogurt

# %%
# a dictionary of formatted names (lower & remove white spice) and new names to be returned
new_names = {'yifangtaiwanfruittea':'Yi Fang Taiwan Fruit Tea',
             'vivibubbletea':'Vivi Bubble Tea',
             'jooyteashoppe':'JOOY Tea Shop',
             'tbaar':'TBaar',
             'cocofreshtea&juice':'CoCo Fresh Tea & Juice',
             "yomie'sricexyogurt":"Yomie's Rice X Yogurt",
             'pokébowlstation':'PokéBowl Station'}

names_counts['name_lower'] = names_counts['name_lower'].replace(new_names)

names_counts
# Out:
#                          name  counts                name_lower
# 4      CoCo Fresh Tea & Juice       6    CoCo Fresh Tea & Juice
# 7      Coco Fresh Tea & Juice       4    CoCo Fresh Tea & Juice
# 152           JOOY TEA SHOPPE       1             JOOY Tea Shop
# 125           JOOY Tea Shoppe       1             JOOY Tea Shop
# 70            Jooy Tea Shoppe       1             JOOY Tea Shop
# 32           PokéBowl Station       2          PokéBowl Station
# 235          Pokébowl Station       1          PokéBowl Station
# 8                       TBaar       4                     TBaar
# 16                      Tbaar       3                     TBaar
# 126                    T Baar       1                     TBaar
# 2             ViVi Bubble Tea      19           Vivi Bubble Tea
# 264           ViVi Bubble tea       1           Vivi Bubble Tea
# 6             Vivi Bubble Tea       5           Vivi Bubble Tea
# 36   Yi Fang Taiwan Fruit Tea       2  Yi Fang Taiwan Fruit Tea
# 18    Yifang Taiwan Fruit Tea       3  Yi Fang Taiwan Fruit Tea
# 35    YiFang Taiwan Fruit Tea       2  Yi Fang Taiwan Fruit Tea
# 121     Yomie's Rice x Yogurt       1     Yomie's Rice X Yogurt
# 42      Yomie's Rice X Yogurt       1     Yomie's Rice X Yogurt

# %%
# a dictionary of old and new names to be returned
replace_duplicates = dict(zip(names_counts['name'], names_counts['name_lower']))

replace_duplicates
# Out:
# {'CoCo Fresh Tea & Juice': 'CoCo Fresh Tea & Juice',
#  'Coco Fresh Tea & Juice': 'CoCo Fresh Tea & Juice',
#  'JOOY TEA SHOPPE': 'JOOY Tea Shop',
#  'JOOY Tea Shoppe': 'JOOY Tea Shop',
#  'Jooy Tea Shoppe': 'JOOY Tea Shop',
#  'PokéBowl Station': 'PokéBowl Station',
#  'Pokébowl Station': 'PokéBowl Station',
#  'TBaar': 'TBaar',
#  'Tbaar': 'TBaar',
#  'T Baar': 'TBaar',
#  'ViVi Bubble Tea': 'Vivi Bubble Tea',
#  'ViVi Bubble tea': 'Vivi Bubble Tea',
#  'Vivi Bubble Tea': 'Vivi Bubble Tea',
#  'Yi Fang Taiwan Fruit Tea': 'Yi Fang Taiwan Fruit Tea',
#  'Yifang Taiwan Fruit Tea': 'Yi Fang Taiwan Fruit Tea',
#  'YiFang Taiwan Fruit Tea': 'Yi Fang Taiwan Fruit Tea',
#  "Yomie's Rice x Yogurt": "Yomie's Rice X Yogurt",
#  "Yomie's Rice X Yogurt": "Yomie's Rice X Yogurt"}

# %%
# replace old and new names to original dataframe
df['name'] = df['name'].replace(replace_duplicates)

df.head()
# Out:
#                        id                             alias  \
# 0  Q3fmTHT7zilDWtfzLK9lMA                truedan-new-york-3
# 1  7-bx74TooPuZKZDNW4WFcQ            chun-yang-tea-new-york
# 2  3aypSFXLfkAL4dhHVFobKg           lazy-sundaes-new-york-6
# 3  bVJQEeRNi34-3XN_F1AZEg             xing-fu-tang-new-york
# 4  zupVwJAFYkHDwrsQd2ktXA  fiftylan-union-square-new-york-3
#
#                     name                                          image_url  \
# 0                Truedan  https://s3-media2.fl.yelpcdn.com/bphoto/BmUZXO...
# 1          Chun Yang Tea  https://s3-media1.fl.yelpcdn.com/bphoto/JrGwrZ...
# 2           Lazy Sundaes  https://s3-media3.fl.yelpcdn.com/bphoto/kEfCYC...
# 3           Xing Fu Tang  https://s3-media2.fl.yelpcdn.com/bphoto/cyFHFE...
# 4  FIFTYLAN Union Square  https://s3-media3.fl.yelpcdn.com/bphoto/UIwR20...
#
#    is_closed                                                url  review_count  \
# 0      False  https://www.yelp.com/biz/truedan-new-york-3?ad...            99
# 1      False  https://www.yelp.com/biz/chun-yang-tea-new-yor...            91
# 2      False  https://www.yelp.com/biz/lazy-sundaes-new-york...            32
# 3      False  https://www.yelp.com/biz/xing-fu-tang-new-york...            89
# 4      False  https://www.yelp.com/biz/fiftylan-union-square...            59
#
#                                           categories  rating  \
# 0    [{'alias': 'bubbletea', 'title': 'Bubble Tea'}]     4.5
# 1    [{'alias': 'bubbletea', 'title': 'Bubble Tea'}]     4.5
# 2  [{'alias': 'bubbletea', 'title': 'Bubble Tea'}...     4.5
# 3    [{'alias': 'bubbletea', 'title': 'Bubble Tea'}]     4.5
# 4    [{'alias': 'bubbletea', 'title': 'Bubble Tea'}]     4.0
#
#                                          coordinates            transactions  \
# 0  {'latitude': 40.7191742, 'longitude': -73.9962...  ['delivery', 'pickup']
# 1      {'latitude': 40.71617, 'longitude': -73.9971}  ['delivery', 'pickup']
# 2   {'latitude': 40.720597, 'longitude': -73.984539}  ['delivery', 'pickup']
# 3      {'latitude': 40.7288, 'longitude': -73.98775}  ['delivery', 'pickup']
# 4   {'latitude': 40.735516, 'longitude': -73.989191}  ['delivery', 'pickup']
#
#   price                                           location         phone  \
# 0    $$  {'address1': '208 Grand St', 'address2': None,...  1.646559e+10
# 1    $$  {'address1': '26B Elizabeth St', 'address2': '...  1.212420e+10
# 2    $$  {'address1': '23 Clinton St', 'address2': None...           NaN
# 3   NaN  {'address1': '133 2nd Ave', 'address2': '', 'a...           NaN
# 4   NaN  {'address1': '32 Union Square E', 'address2': ...  1.646767e+10
#
#     display_phone     distance   latitude  longitude  \
# 0  (646) 559-2886  1535.241614  40.719174 -73.996220
# 1  (212) 420-0123  1212.877370  40.716170 -73.997100
# 2             NaN  1877.016204  40.720597 -73.984539
# 3             NaN  2656.450427  40.728800 -73.987750
# 4  (646) 767-0085  3367.900728  40.735516 -73.989191
#
#                                geometry
# 0        POINT (-73.9962197 40.7191742)
# 1             POINT (-73.9971 40.71617)
# 2          POINT (-73.984539 40.720597)
# 3    POINT (-73.98775000000001 40.7288)
# 4  POINT (-73.98919100000001 40.735516)

# %%
df.to_csv('boba-nyc-cleaned.csv', index=False)

# %%
# count of unique values of bubble tea shops
df['name'].value_counts()
# Out:
# Kung Fu Tea                    26
# Vivi Bubble Tea                25
# Gong Cha                       24
# CoCo Fresh Tea & Juice         10
# Möge Tee                        9
#                                ..
# Honestea                        1
# Mochinut Bayside                1
# Creep City Ninja Bubble Tea     1
# Newkirk Fruit                   1
# Boba Fries                      1
# Name: name, Length: 258, dtype: int64

# %%
df['name'].value_counts().reset_index(drop=False)
# Out:
#                            index  name
# 0                    Kung Fu Tea    26
# 1                Vivi Bubble Tea    25
# 2                       Gong Cha    24
# 3         CoCo Fresh Tea & Juice    10
# 4                       Möge Tee     9
# ..                           ...   ...
# 253                     Honestea     1
# 254             Mochinut Bayside     1
# 255  Creep City Ninja Bubble Tea     1
# 256                Newkirk Fruit     1
# 257                   Boba Fries     1
#
# [258 rows x 2 columns]

# %%
names_counts = df['name'].value_counts().reset_index(drop=False)
names_counts = names_counts.rename(columns={'index':'names', 'name':'counts'})

fig, ax = plt.subplots(figsize=(8, 6))

sns.barplot(x='counts',
            y="names", 
            data=names_counts.head(10), 
            ax=ax)

plt.title('Number of bubble tea shops by business in nyc', fontsize=15)
plt.tight_layout()

# %%
review_count_df = df.groupby(by='name')['review_count'].mean().sort_values(ascending=False)
review_count_df = round(review_count_df, 2)
review_count_df = review_count_df.reset_index()

review_count_df.head()
# Out:
#                  name  review_count
# 0  Ten Ren's Tea Time        655.00
# 1             Hanco's        519.33
# 2        Ajisen Ramen        438.00
# 3      Teado Tea Shop        426.00
# 4         520 Dessert        358.00

# %%
fig, ax = plt.subplots(figsize=(8, 6))

sns.barplot(x="review_count", 
            y="name", 
            data=review_count_df.head(20), 
            ax=ax)

plt.title('Average number of reviews per business in nyc', fontsize=15)
plt.tight_layout()

# %%
most_reviewed = df.sort_values(by='review_count', ascending=False).head(20)

most_reviewed.head()
# Out:
#                          id                           alias  \
# 170  bn0zZ9nT_j1INOwfpxWmEw            tiger-sugar-flushing
# 88   NqnYnZtajJ4Y-Lmxa26VdA                 hancos-brooklyn
# 50   WxNlqGSsj_2TCodkx9Sa4A      vivi-bubble-tea-new-york-6
# 45   SqVHETmH6bf3rPKmdftvvw    ten-rens-tea-time-new-york-2
# 272  ZLo3HRSSvN--Mw4eCBLxCg  mango-mango-dessert-flushing-3
#
#                     name                                          image_url  \
# 170          Tiger Sugar  https://s3-media3.fl.yelpcdn.com/bphoto/Psre6b...
# 88               Hanco's  https://s3-media3.fl.yelpcdn.com/bphoto/_vQWWX...
# 50       Vivi Bubble Tea  https://s3-media2.fl.yelpcdn.com/bphoto/Fw3SYB...
# 45    Ten Ren's Tea Time  https://s3-media1.fl.yelpcdn.com/bphoto/UChdn5...
# 272  Mango Mango Dessert  https://s3-media4.fl.yelpcdn.com/bphoto/9zl6pk...
#
#      is_closed                                                url  \
# 170      False  https://www.yelp.com/biz/tiger-sugar-flushing?...
# 88       False  https://www.yelp.com/biz/hancos-brooklyn?adjus...
# 50       False  https://www.yelp.com/biz/vivi-bubble-tea-new-y...
# 45       False  https://www.yelp.com/biz/ten-rens-tea-time-new...
# 272      False  https://www.yelp.com/biz/mango-mango-dessert-f...
#
#      review_count                                         categories  rating  \
# 170           740  [{'alias': 'bubbletea', 'title': 'Bubble Tea'}...     4.0
# 88            705  [{'alias': 'vietnamese', 'title': 'Vietnamese'...     4.0
# 50            658    [{'alias': 'bubbletea', 'title': 'Bubble Tea'}]     4.0
# 45            655    [{'alias': 'bubbletea', 'title': 'Bubble Tea'}]     4.0
# 272           620  [{'alias': 'desserts', 'title': 'Desserts'}, {...     4.0
#
#                                            coordinates  \
# 170  {'latitude': 40.75922023369396, 'longitude': -...
# 88   {'latitude': 40.6870318621828, 'longitude': -7...
# 50    {'latitude': 40.715099, 'longitude': -73.997535}
# 45   {'latitude': 40.7163819, 'longitude': -73.9982...
# 272  {'latitude': 40.7603809317017, 'longitude': -7...
#
#                transactions price  \
# 170  ['pickup', 'delivery']    $$
# 88   ['delivery', 'pickup']     $
# 50   ['delivery', 'pickup']     $
# 45             ['delivery']    $$
# 272  ['delivery', 'pickup']     $
#
#                                               location         phone  \
# 170  {'address1': '40-10 Main St', 'address2': 'Ste...  1.347732e+10
# 88   {'address1': '134 Smith St', 'address2': '', '...  1.718859e+10
# 50   {'address1': '49 Bayard St', 'address2': '', '...  1.212567e+10
# 45   {'address1': '73 Mott St', 'address2': '', 'ad...  1.212733e+10
# 272  {'address1': '136-28 39th Ave', 'address2': ''...  1.917563e+10
#
#       display_phone      distance   latitude  longitude  \
# 170  (347) 732-4001  15055.920826  40.759220 -73.830305
# 88   (718) 858-6818   2073.182530  40.687032 -73.990429
# 50   (212) 566-6833   1114.073275  40.715099 -73.997535
# 45   (212) 732-7178   1261.450313  40.716382 -73.998268
# 272  (917) 563-1847  15199.500511  40.760381 -73.829452
#
#                                          geometry
# 170  POINT (-73.83030496537685 40.75922023369396)
# 88     POINT (-73.9904292380982 40.6870318621828)
# 50                   POINT (-73.997535 40.715099)
# 45          POINT (-73.99826830000001 40.7163819)
# 272    POINT (-73.8294516357502 40.7603809317017)

# %%
fig, ax = plt.subplots(figsize=(8, 6))

sns.barplot(x="review_count", 
            y="alias", 
            data=most_reviewed, 
            ax=ax)

plt.title('Most reviews per business location in nyc', fontsize=15)
plt.tight_layout()

# %%
df['rating'].describe()
# Out:
# count    413.000000
# mean       3.991525
# std        0.605838
# min        1.000000
# 25%        3.500000
# 50%        4.000000
# 75%        4.500000
# max        5.000000
# Name: rating, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(8, 6))

sns.countplot(data=df, 
             x="rating")

plt.title('Count of ratings per business location in nyc', fontsize=15)
plt.tight_layout()

# %%
price_df = df['price'].dropna().value_counts()
price_df = price_df.reset_index()
price_df.columns = ['price', 'counts']

price_df
# Out:
#   price  counts
# 0     $     168
# 1    $$      89
# 2  $$$$       1

# %%
price_df['price'] = price_df['price'].str.count('\\$')

price_df
# Out:
#    price  counts
# 0      1     168
# 1      2      89
# 2      4       1

# %%
fig, ax = plt.subplots(figsize=(8, 6))

sns.barplot(y="counts", 
            x="price", 
            data=price_df, 
            ax=ax)

plt.title('Price level (1 = $) per business location in NYC', fontsize=15)
plt.tight_layout()

# %%
url = 'https://data.cityofnewyork.us/api/geospatial/cpf4-rkhq?method=export&format=Shapefile'
neighborhoods = gpd.read_file(url)

neighborhoods.head()
# Out:
#    boro_code  boro_name county_fip ntacode  \
# 0        4.0     Queens        081    QN51
# 1        4.0     Queens        081    QN27
# 2        4.0     Queens        081    QN41
# 3        1.0  Manhattan        061    MN17
# 4        2.0      Bronx        005    BX09
#
#                                            ntaname    shape_area  \
# 0                                      Murray Hill  5.248828e+07
# 1                                    East Elmhurst  1.972685e+07
# 2                             Fresh Meadows-Utopia  2.777485e+07
# 3                            Midtown-Midtown South  3.019153e+07
# 4  Soundview-Castle Hill-Clason Point-Harding Park  5.198380e+07
#
#      shape_leng                                           geometry
# 0  33266.904856  POLYGON ((-73.80379 40.77561, -73.80099 40.775...
# 1  19816.711894  POLYGON ((-73.86110 40.76366, -73.85993 40.762...
# 2  22106.431272  POLYGON ((-73.77758 40.73019, -73.77849 40.729...
# 3  27032.700375  POLYGON ((-73.97301 40.76428, -73.97141 40.763...
# 4  67340.977626  MULTIPOLYGON (((-73.88064 40.81852, -73.88098 ...

# %%
neighborhoods.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
neighborhoods = neighborhoods.to_crs('EPSG:4326')

neighborhoods.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
df.head()
# Out:
#                        id                             alias  \
# 0  Q3fmTHT7zilDWtfzLK9lMA                truedan-new-york-3
# 1  7-bx74TooPuZKZDNW4WFcQ            chun-yang-tea-new-york
# 2  3aypSFXLfkAL4dhHVFobKg           lazy-sundaes-new-york-6
# 3  bVJQEeRNi34-3XN_F1AZEg             xing-fu-tang-new-york
# 4  zupVwJAFYkHDwrsQd2ktXA  fiftylan-union-square-new-york-3
#
#                     name                                          image_url  \
# 0                Truedan  https://s3-media2.fl.yelpcdn.com/bphoto/BmUZXO...
# 1          Chun Yang Tea  https://s3-media1.fl.yelpcdn.com/bphoto/JrGwrZ...
# 2           Lazy Sundaes  https://s3-media3.fl.yelpcdn.com/bphoto/kEfCYC...
# 3           Xing Fu Tang  https://s3-media2.fl.yelpcdn.com/bphoto/cyFHFE...
# 4  FIFTYLAN Union Square  https://s3-media3.fl.yelpcdn.com/bphoto/UIwR20...
#
#    is_closed                                                url  review_count  \
# 0      False  https://www.yelp.com/biz/truedan-new-york-3?ad...            99
# 1      False  https://www.yelp.com/biz/chun-yang-tea-new-yor...            91
# 2      False  https://www.yelp.com/biz/lazy-sundaes-new-york...            32
# 3      False  https://www.yelp.com/biz/xing-fu-tang-new-york...            89
# 4      False  https://www.yelp.com/biz/fiftylan-union-square...            59
#
#                                           categories  rating  \
# 0    [{'alias': 'bubbletea', 'title': 'Bubble Tea'}]     4.5
# 1    [{'alias': 'bubbletea', 'title': 'Bubble Tea'}]     4.5
# 2  [{'alias': 'bubbletea', 'title': 'Bubble Tea'}...     4.5
# 3    [{'alias': 'bubbletea', 'title': 'Bubble Tea'}]     4.5
# 4    [{'alias': 'bubbletea', 'title': 'Bubble Tea'}]     4.0
#
#                                          coordinates            transactions  \
# 0  {'latitude': 40.7191742, 'longitude': -73.9962...  ['delivery', 'pickup']
# 1      {'latitude': 40.71617, 'longitude': -73.9971}  ['delivery', 'pickup']
# 2   {'latitude': 40.720597, 'longitude': -73.984539}  ['delivery', 'pickup']
# 3      {'latitude': 40.7288, 'longitude': -73.98775}  ['delivery', 'pickup']
# 4   {'latitude': 40.735516, 'longitude': -73.989191}  ['delivery', 'pickup']
#
#   price                                           location         phone  \
# 0    $$  {'address1': '208 Grand St', 'address2': None,...  1.646559e+10
# 1    $$  {'address1': '26B Elizabeth St', 'address2': '...  1.212420e+10
# 2    $$  {'address1': '23 Clinton St', 'address2': None...           NaN
# 3   NaN  {'address1': '133 2nd Ave', 'address2': '', 'a...           NaN
# 4   NaN  {'address1': '32 Union Square E', 'address2': ...  1.646767e+10
#
#     display_phone     distance   latitude  longitude  \
# 0  (646) 559-2886  1535.241614  40.719174 -73.996220
# 1  (212) 420-0123  1212.877370  40.716170 -73.997100
# 2             NaN  1877.016204  40.720597 -73.984539
# 3             NaN  2656.450427  40.728800 -73.987750
# 4  (646) 767-0085  3367.900728  40.735516 -73.989191
#
#                                geometry
# 0        POINT (-73.9962197 40.7191742)
# 1             POINT (-73.9971 40.71617)
# 2          POINT (-73.984539 40.720597)
# 3    POINT (-73.98775000000001 40.7288)
# 4  POINT (-73.98919100000001 40.735516)

# %%
gdf = gpd.GeoDataFrame(df, crs=4326,
      geometry=gpd.points_from_xy(df.longitude, df.latitude))

gdf.head()
# Out:
#                        id                             alias  \
# 0  Q3fmTHT7zilDWtfzLK9lMA                truedan-new-york-3
# 1  7-bx74TooPuZKZDNW4WFcQ            chun-yang-tea-new-york
# 2  3aypSFXLfkAL4dhHVFobKg           lazy-sundaes-new-york-6
# 3  bVJQEeRNi34-3XN_F1AZEg             xing-fu-tang-new-york
# 4  zupVwJAFYkHDwrsQd2ktXA  fiftylan-union-square-new-york-3
#
#                     name                                          image_url  \
# 0                Truedan  https://s3-media2.fl.yelpcdn.com/bphoto/BmUZXO...
# 1          Chun Yang Tea  https://s3-media1.fl.yelpcdn.com/bphoto/JrGwrZ...
# 2           Lazy Sundaes  https://s3-media3.fl.yelpcdn.com/bphoto/kEfCYC...
# 3           Xing Fu Tang  https://s3-media2.fl.yelpcdn.com/bphoto/cyFHFE...
# 4  FIFTYLAN Union Square  https://s3-media3.fl.yelpcdn.com/bphoto/UIwR20...
#
#    is_closed                                                url  review_count  \
# 0      False  https://www.yelp.com/biz/truedan-new-york-3?ad...            99
# 1      False  https://www.yelp.com/biz/chun-yang-tea-new-yor...            91
# 2      False  https://www.yelp.com/biz/lazy-sundaes-new-york...            32
# 3      False  https://www.yelp.com/biz/xing-fu-tang-new-york...            89
# 4      False  https://www.yelp.com/biz/fiftylan-union-square...            59
#
#                                           categories  rating  \
# 0    [{'alias': 'bubbletea', 'title': 'Bubble Tea'}]     4.5
# 1    [{'alias': 'bubbletea', 'title': 'Bubble Tea'}]     4.5
# 2  [{'alias': 'bubbletea', 'title': 'Bubble Tea'}...     4.5
# 3    [{'alias': 'bubbletea', 'title': 'Bubble Tea'}]     4.5
# 4    [{'alias': 'bubbletea', 'title': 'Bubble Tea'}]     4.0
#
#                                          coordinates            transactions  \
# 0  {'latitude': 40.7191742, 'longitude': -73.9962...  ['delivery', 'pickup']
# 1      {'latitude': 40.71617, 'longitude': -73.9971}  ['delivery', 'pickup']
# 2   {'latitude': 40.720597, 'longitude': -73.984539}  ['delivery', 'pickup']
# 3      {'latitude': 40.7288, 'longitude': -73.98775}  ['delivery', 'pickup']
# 4   {'latitude': 40.735516, 'longitude': -73.989191}  ['delivery', 'pickup']
#
#   price                                           location         phone  \
# 0    $$  {'address1': '208 Grand St', 'address2': None,...  1.646559e+10
# 1    $$  {'address1': '26B Elizabeth St', 'address2': '...  1.212420e+10
# 2    $$  {'address1': '23 Clinton St', 'address2': None...           NaN
# 3   NaN  {'address1': '133 2nd Ave', 'address2': '', 'a...           NaN
# 4   NaN  {'address1': '32 Union Square E', 'address2': ...  1.646767e+10
#
#     display_phone     distance   latitude  longitude  \
# 0  (646) 559-2886  1535.241614  40.719174 -73.996220
# 1  (212) 420-0123  1212.877370  40.716170 -73.997100
# 2             NaN  1877.016204  40.720597 -73.984539
# 3             NaN  2656.450427  40.728800 -73.987750
# 4  (646) 767-0085  3367.900728  40.735516 -73.989191
#
#                      geometry
# 0  POINT (-73.99622 40.71917)
# 1  POINT (-73.99710 40.71617)
# 2  POINT (-73.98454 40.72060)
# 3  POINT (-73.98775 40.72880)
# 4  POINT (-73.98919 40.73552)

# %%
join_df = gpd.sjoin(gdf, 
                    neighborhoods, 
                    op='intersects') 

join_df.head()
# Out:
#                         id                      alias            name  \
# 0   Q3fmTHT7zilDWtfzLK9lMA         truedan-new-york-3         Truedan
# 15  DbhBca8LzskjS0B-L4QfZg       tiger-sugar-new-york     Tiger Sugar
# 28  bxCjNLVDQggNTbpviV0RMw    lazy-sundaes-new-york-4    Lazy Sundaes
# 60  jsJdz6pvyYZjtut9vkUwBw  yaya-tea-grand-new-york-2  Yaya Tea Grand
# 72  uge-Lp_kY1J6Z4CzzceULw          honestea-new-york        Honestea
#
#                                             image_url  is_closed  \
# 0   https://s3-media2.fl.yelpcdn.com/bphoto/BmUZXO...      False
# 15  https://s3-media3.fl.yelpcdn.com/bphoto/5wNVyj...      False
# 28  https://s3-media3.fl.yelpcdn.com/bphoto/iDul5E...      False
# 60  https://s3-media2.fl.yelpcdn.com/bphoto/iutBCc...      False
# 72  https://s3-media1.fl.yelpcdn.com/bphoto/77X7Xd...      False
#
#                                                   url  review_count  \
# 0   https://www.yelp.com/biz/truedan-new-york-3?ad...            99
# 15  https://www.yelp.com/biz/tiger-sugar-new-york?...           512
# 28  https://www.yelp.com/biz/lazy-sundaes-new-york...            65
# 60  https://www.yelp.com/biz/yaya-tea-grand-new-yo...           295
# 72  https://www.yelp.com/biz/honestea-new-york?adj...           103
#
#                                            categories  rating  \
# 0     [{'alias': 'bubbletea', 'title': 'Bubble Tea'}]     4.5
# 15    [{'alias': 'bubbletea', 'title': 'Bubble Tea'}]     4.0
# 28  [{'alias': 'bubbletea', 'title': 'Bubble Tea'}...     4.0
# 60  [{'alias': 'bubbletea', 'title': 'Bubble Tea'}...     4.0
# 72  [{'alias': 'bubbletea', 'title': 'Bubble Tea'}...     3.5
#
#                                           coordinates  ...  longitude  \
# 0   {'latitude': 40.7191742, 'longitude': -73.9962...  ... -73.996220
# 15  {'latitude': 40.717891007822274, 'longitude': ...  ... -73.999780
# 28  {'latitude': 40.7189689, 'longitude': -74.0006...  ... -74.000677
# 60  {'latitude': 40.7192268371582, 'longitude': -7...  ... -73.996277
# 72     {'latitude': 40.71789, 'longitude': -73.99692}  ... -73.996920
#
#                       geometry index_right  boro_code  boro_name  county_fip  \
# 0   POINT (-73.99622 40.71917)          94        1.0  Manhattan         061
# 15  POINT (-73.99978 40.71789)          94        1.0  Manhattan         061
# 28  POINT (-74.00068 40.71897)          94        1.0  Manhattan         061
# 60  POINT (-73.99628 40.71923)          94        1.0  Manhattan         061
# 72  POINT (-73.99692 40.71789)          94        1.0  Manhattan         061
#
#     ntacode                                 ntaname    shape_area  \
# 0      MN24  SoHo-TriBeCa-Civic Center-Little Italy  2.503268e+07
# 15     MN24  SoHo-TriBeCa-Civic Center-Little Italy  2.503268e+07
# 28     MN24  SoHo-TriBeCa-Civic Center-Little Italy  2.503268e+07
# 60     MN24  SoHo-TriBeCa-Civic Center-Little Italy  2.503268e+07
# 72     MN24  SoHo-TriBeCa-Civic Center-Little Italy  2.503268e+07
#
#       shape_leng
# 0   26855.031527
# 15  26855.031527
# 28  26855.031527
# 60  26855.031527
# 72  26855.031527
#
# [5 rows x 27 columns]

# %%
join_df = join_df.groupby(by=['ntaname', 'shape_area'])['id'].count().sort_values(ascending=False)
join_df = join_df.reset_index()

join_df = join_df.rename(columns={'id':'counts'})
join_df['counts_squaremile'] = join_df['counts'] / 27878400

join_df.head()
# Out:
#                                 ntaname    shape_area  counts  \
# 0                              Flushing  3.786424e+07      40
# 1                             Chinatown  1.450188e+07      28
# 2                      Sunset Park East  2.711007e+07      23
# 3  Hunters Point-Sunnyside-West Maspeth  1.024191e+08      19
# 4                              Elmhurst  3.267480e+07      17
#
#    counts_squaremile
# 0       1.434803e-06
# 1       1.004362e-06
# 2       8.250115e-07
# 3       6.815312e-07
# 4       6.097911e-07

# %%
fig, ax = plt.subplots(figsize=(10, 6))

sns.barplot(x="counts", 
            y="ntaname", 
            data=join_df.head(20), 
            ax=ax)

plt.title('Most bubble tea locations per neighborhood in NYC', fontsize=15)
plt.ylabel('neighborhood')
plt.xlabel('count per square mile')

plt.tight_layout()
plt.savefig('busineses-per-neighborhood.png', dpi=200)

# %%
fig, ax = plt.subplots(figsize=(10, 6))

sns.barplot(x="counts_squaremile", 
            y="ntaname", 
            data=join_df.head(20), 
            ax=ax)

plt.title('Most bubble tea locations per neighborhood square mile in NYC', fontsize=15)
plt.ylabel('neighborhood')
plt.xlabel('count per square mile')

plt.tight_layout()
plt.savefig('busineses-per-neighborhood.png', dpi=200)
